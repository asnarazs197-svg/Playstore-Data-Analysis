# %% [markdown]
# # Playstore Data Analysis

# %% [markdown]
# #### The aim of the analysis is to study the Google Playstore data to understand what makes an app popular. It looks at things like ratings, reviews, category, size, and price.
# #### This is useful because it helps developers and businesses understand what makes an app successful, improve their apps based on user preferences, and make better decisions about pricing, features, and category selection.

# %% [markdown]
# ## importing libraries

# %%
import pandas as pd # data handing
import matplotlib as plt # visualization
import seaborn as sns # visualization

# %% [markdown]
# ## loading data

# %%
df = pd.read_csv("Playstore.csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## inspecting data

# %%
df.head(10)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                         Paper flowers instructions  ART_AND_DESIGN     4.4
# 6            Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                   Infinite Painter  ART_AND_DESIGN     4.1
# 8                               Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                      Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# ...

# %%
df.sample(10)
# Out:
#                                                  App            Category  \
# 3739                                         Twitter  NEWS_AND_MAGAZINES
# 9755   Little Eye Surgery Simulator - ER Doctor Game              FAMILY
# 520   EliteSingles – Dating for Single Professionals              DATING
# 7553                                 CM FILE MANAGER               TOOLS
# 9144                             Madden NFL Football              FAMILY
# 8051                  TI-Nspire CX Calculator Manual              FAMILY
# 3705                            Video Wallpaper Show       VIDEO_PLAYERS
# 3615                        Classical music for baby           PARENTING
# 3805                                         NPR One  NEWS_AND_MAGAZINES
# 9893                               EU CBRNE Glossary  LIBRARIES_AND_DEMO
#
#       Rating   Reviews                Size      Installs  Type  Price  \
# 3739     4.3  11667403  Varies with device  500,000,000+  Free      0
# ...

# %%
df.tail(10)
# Out:
#                                                  App             Category  \
# 10831                       payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                       FR Tides              WEATHER
# 10833                                    Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                  FR Calculator               FAMILY
# 10835                                       FR Forms             BUSINESS
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10831     NaN      38                9.8M       5,000+  Free     0
# ...

# %%
df.dtypes # check the coloumn data type
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.columns # display coloumn names
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.shape # display no. of rows and coloumns
# Out:
# (10841, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# - Rating column has 1574 missing count
# - Type column had 1 missing count
# - Content Rating has 1 missing count
# - Current Ver has 8 missing count
# - Android Ver has 3 missing count

# %% [markdown]
# ## Selecting single Column

# %%
df['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %% [markdown]
# ## Selecting multiple columns

# %%
new = df[['App','Size']]
new
# Out:
#                                                      App                Size
# 0         Photo Editor & Candy Camera & Grid & ScrapBook                 19M
# 1                                    Coloring book moana                 14M
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...                8.7M
# 3                                  Sketch - Draw & Paint                 25M
# 4                  Pixel Draw - Number Art Coloring Book                2.8M
# ...                                                  ...                 ...
# 10836                                   Sya9a Maroc - FR                 53M
# 10837                   Fr. Mike Schmitz Audio Teachings                3.6M
# 10838                             Parkinson Exercices FR                9.5M
# 10839                      The SCP Foundation DB fr nn5n  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology                 19M
#
# [10841 rows x 2 columns]

# %%
print(new)
# Out:
#                                                      App                Size
# 0         Photo Editor & Candy Camera & Grid & ScrapBook                 19M
# 1                                    Coloring book moana                 14M
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...                8.7M
# 3                                  Sketch - Draw & Paint                 25M
# 4                  Pixel Draw - Number Art Coloring Book                2.8M
# ...                                                  ...                 ...
# 10836                                   Sya9a Maroc - FR                 53M
# 10837                   Fr. Mike Schmitz Audio Teachings                3.6M
# 10838                             Parkinson Exercices FR                9.5M
# 10839                      The SCP Foundation DB fr nn5n  Varies with device
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology                 19M
#
# [10841 rows x 2 columns]

# %% [markdown]
# ## Filtering

# %%
df[df['Rating']<4.0]
# Out:
#                                            App             Category  Rating  \
# 1                          Coloring book moana       ART_AND_DESIGN     3.9
# 6      Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN     3.8
# 15             Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2
# 28                       Pencil Sketch Drawing       ART_AND_DESIGN     3.9
# 35            How to draw Ladybug and Cat Noir       ART_AND_DESIGN     3.8
# ...                                        ...                  ...     ...
# 10782                  Trine 2: Complete Story                 GAME     3.8
# 10819                                Fanfic-FR  BOOKS_AND_REFERENCE     3.3
# 10828                  Manga-FR - Anime Vostfr               COMICS     3.4
# 10830                        News Minecraft.fr   NEWS_AND_MAGAZINES     3.8
# 10832                                 FR Tides              WEATHER     3.8
#
# ...

# %%
df[df['Rating']==4.0]
# Out:
#                                                  App           Category  \
# 20                       Logo Maker - Small Business     ART_AND_DESIGN
# 39     How To Color Disney Princess - Coloring Pages     ART_AND_DESIGN
# 50                              Real Tractor Farming  AUTO_AND_VEHICLES
# 58                                 Restart Navigator  AUTO_AND_VEHICLES
# 66                                  Used Cars Mexico  AUTO_AND_VEHICLES
# ...                                              ...                ...
# 10802                            FR: My Famous Lover             FAMILY
# 10814                            FR: My Secret Pets!             FAMILY
# 10817                           HTC Sense Input - FR              TOOLS
# 10826      Frim: get new friends on local chat rooms             SOCIAL
# 10834                                  FR Calculator             FAMILY
#
#        Rating Reviews                Size    Installs  Type Price  \
# ...

# %%
df[df['Content Rating']=='Everyone']
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# 5                             Paper flowers instructions  ART_AND_DESIGN
# ...                                                  ...             ...
# 10835                                           FR Forms        BUSINESS
# 10836                                   Sya9a Maroc - FR          FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10838                             Parkinson Exercices FR         MEDICAL
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology       LIFESTYLE
#
#        Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
df[df['Type']=='Paid']
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 290    TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating Reviews                Size  Installs  Type   Price  \
# ...

# %% [markdown]
# ## Filtering with multiple conditions

# %%
df[(df['Rating']==4.0)&(df['Type']=='Paid')]
# Out:
#                                                     App         Category  \
# 427                                  Puffin Browser Pro    COMMUNICATION
# 2175                       Whoowasit? - Best kids game!           FAMILY
# 2261                                        Block Buddy          MEDICAL
# 2389                                        Block Buddy          MEDICAL
# 2414                                       LTC AS Legal          MEDICAL
# 4456          [Sub/EMUI] P Pro - EMUI 8.1/8.0/5.X Theme  PERSONALIZATION
# 4743                                         weather HD  PERSONALIZATION
# 4789                  X Home Bar - Home Bar Gesture Pro            TOOLS
# 5354                                     I am Rich Plus           FAMILY
# 5367                                         I am Bread             GAME
# 5373                                 I AM RICH PRO PLUS          FINANCE
# 6440                                    MEGA MAN MOBILE             GAME
# ...

# %% [markdown]
# ## Selecting raws

# %%
df.iloc[11] #single raw
# Out:
# App               Name Art Photo Editor - Focus n Filters
# Category                                   ART_AND_DESIGN
# Rating                                                4.4
# Reviews                                              8788
# Size                                                  12M
# Installs                                       1,000,000+
# Type                                                 Free
# Price                                                   0
# Content Rating                                   Everyone
# Genres                                       Art & Design
# Last Updated                                July 31, 2018
# Current Ver                                        1.0.15
# Android Ver                                    4.0 and up
# Name: 11, dtype: object

# %%
df.iloc[1:5] #portion
# Out:
#                                                  App        Category  Rating  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# ...

# %% [markdown]
# ## Loc Method

# %%
df.loc[200,'Rating']
# Out:
# np.float64(4.3)

# %%
df.loc[456,'Size']
# Out:
# '7.3M'

# %% [markdown]
# ## Rename column

# %% [markdown]
# ### Rename single column

# %%
df.rename(columns={"App":"Application"},inplace=True)     #Renaming App as Application
df
# Out:
#                                              Application             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ### Rename multiple columns

# %%
df.rename(columns={"Category":"section","Type":"item"},inplace=True) #Renaming Category as Section and Type as Item
df
# Out:
#                                              Application              section  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## Value counts

# %%
df['Size'].value_counts()
# Out:
# Size
# Varies with device    1695
# 11M                    198
# 12M                    196
# 14M                    194
# 13M                    191
#                       ...
# 429k                     1
# 200k                     1
# 460k                     1
# 728k                     1
# 619k                     1
# Name: count, Length: 462, dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
df['Installs'] = pd.to_numeric(df['Installs'].astype(str).str.replace(r'[^0-9.-]','',regex=True).replace('',None),errors='coerce')
df   #
# Out:
#                                              Application              section  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.head()
# Out:
#                                          Application         section  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size    Installs  item Price Content Rating  \
# 0     159   19M     10000.0  Free     0       Everyone
# 1     967   14M    500000.0  Free     0       Everyone
# 2   87510  8.7M   5000000.0  Free     0       Everyone
# 3  215644   25M  50000000.0  Free     0           Teen
# 4     967  2.8M    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Price'] = pd.to_numeric(df['Price'].astype(str).str.replace(r'[^0-9.-]','',regex=True).replace('',None),errors='coerce')

# %%
df["Last Updated"] = pd.to_datetime(df["Last Updated"],errors="coerce")
df
# Out:
#                                              Application              section  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.tail()
# Out:
#                                          Application              section  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size    Installs  item  Price  \
# 10836     4.5      38                 53M      5000.0  Free    0.0
# 10837     5.0       4                3.6M       100.0  Free    0.0
# 10838     NaN       3                9.5M      1000.0  Free    0.0
# 10839     4.5     114  Varies with device      1000.0  Free    0.0
# 10840     4.5  398307                 19M  10000000.0  Free    0.0
#
#       Content Rating             Genres Last Updated         Current Ver  \
# ...

# %%
# df['Size'] = pd.to_numeric(df['Size'].astype(str).str.replace(r'[^0-9.-]','',regex=True).replace('',None),errors='coerce')
df
# Out:
#                                              Application              section  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## Converting size

# %%
df.dtypes
# Out:
# Application               object
# section                   object
# Rating                   float64
# Reviews                   object
# Size                      object
# Installs                 float64
# item                      object
# Price                    float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# dtype: object

# %%
def convert_size(size):
    if size == "Varies with device":
        return None
    elif "M" in size:
        return float(size.replace("M",""))
    elif "K" in size:
        return float(size.replace("K","")) / 1024
    else:
        return None

# %%
df["Size_MB"] = df["Size"].apply(convert_size)

# %% [markdown]
# ## Deleting the coloumn

# %%
df.drop(columns=['Size'],inplace=True)

# %%
df.head()
# Out:
#                                          Application         section  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews    Installs  item  Price Content Rating                     Genres  \
# 0     159     10000.0  Free    0.0       Everyone               Art & Design
# 1     967    500000.0  Free    0.0       Everyone  Art & Design;Pretend Play
# 2   87510   5000000.0  Free    0.0       Everyone               Art & Design
# 3  215644  50000000.0  Free    0.0           Teen               Art & Design
# 4     967    100000.0  Free    0.0       Everyone    Art & Design;Creativity
#
# ...

# %%
df['Reviews'] = pd.to_numeric(df['Reviews'].astype(str).str.replace(r'[^0-9.-]','',regex=True).replace('',None),errors='coerce')
df
# Out:
#                                              Application              section  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Application     10841 non-null  object
#  1   section         10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  float64
#  4   Installs        10840 non-null  float64
#  5   item            10840 non-null  object
#  6   Price           10840 non-null  float64
#  7   Content Rating  10840 non-null  object
#  8   Genres          10841 non-null  object
#  9   Last Updated    10840 non-null  datetime64[ns]
#  10  Current Ver     10833 non-null  object
#  11  Android Ver     10838 non-null  object
#  12  Size_MB         8829 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Handling missing values

# %%
df.isnull().sum()
# Out:
# Application          0
# section              0
# Rating            1474
# Reviews              0
# Installs             1
# item                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         1
# Current Ver          8
# Android Ver          3
# Size_MB           2012
# dtype: int64

# %% [markdown]
# ## Filling missing values

# %%
df['Rating'].fillna(df['Rating'].median(),inplace=True)
df
# Out:
# C:\Users\INTERN\AppData\Local\Temp\ipykernel_15068\1523665828.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rating'].fillna(df['Rating'].median(),inplace=True)
#                                              Application              section  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# ...

# %%
df['Size_MB'].fillna(df['Size_MB'].median(),inplace=True)
df
# Out:
# C:\Users\INTERN\AppData\Local\Temp\ipykernel_15068\2110190827.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Size_MB'].fillna(df['Size_MB'].median(),inplace=True)
#                                              Application              section  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# ...

# %%
df.isnull().sum()
# Out:
# Application       0
# section           0
# Rating            0
# Reviews           0
# Installs          1
# item              1
# Price             1
# Content Rating    1
# Genres            0
# Last Updated      1
# Current Ver       8
# Android Ver       3
# Size_MB           0
# dtype: int64

# %% [markdown]
# ## Deleting missing rows

# %%
df.dropna(subset=['Installs', 'item', 'Price', 'Content Rating', 'Last Updated', 'Current Ver', 'Android Ver'],inplace=True)
df
# Out:
#                                              Application              section  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (10829, 13)

# %%
df.isnull().sum()
# Out:
# Application       0
# section           0
# Rating            0
# Reviews           0
# Installs          0
# item              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# Size_MB           0
# dtype: int64

# %% [markdown]
# ## Handling duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
df = df.drop_duplicates()
df
# Out:
#                                              Application              section  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Verifying data cleaning

# %%
df.head()
# Out:
#                                          Application         section  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews    Installs  item  Price Content Rating  \
# 0     159.0     10000.0  Free    0.0       Everyone
# 1     967.0    500000.0  Free    0.0       Everyone
# 2   87510.0   5000000.0  Free    0.0       Everyone
# 3  215644.0  50000000.0  Free    0.0           Teen
# 4     967.0    100000.0  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10346 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Application     10346 non-null  object
#  1   section         10346 non-null  object
#  2   Rating          10346 non-null  float64
#  3   Reviews         10346 non-null  float64
#  4   Installs        10346 non-null  float64
#  5   item            10346 non-null  object
#  6   Price           10346 non-null  float64
#  7   Content Rating  10346 non-null  object
#  8   Genres          10346 non-null  object
#  9   Last Updated    10346 non-null  datetime64[ns]
#  10  Current Ver     10346 non-null  object
#  11  Android Ver     10346 non-null  object
#  12  Size_MB         10346 non-null  float64
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 1.1+ MB

# %%
df.columns
# Out:
# Index(['Application', 'section', 'Rating', 'Reviews', 'Installs', 'item',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Size_MB'],
#       dtype='object')

# %%
df.shape
# Out:
# (10346, 13)

# %%
df.sample(6)
# Out:
#                           Application        section  Rating     Reviews  \
# 8513   GetThemAll Any File Downloader          TOOLS     4.2     91186.0
# 3904               WhatsApp Messenger  COMMUNICATION     4.4  69109672.0
# 4542                        R-TYPE II           GAME     4.3      5682.0
# 7186               DIY CD Craft Ideas      LIFESTYLE     4.4         5.0
# 8769                      Doctor Kids         FAMILY     4.2    200450.0
# 10779           Fortune Quest: Savior         FAMILY     3.6       135.0
#
#            Installs  item  Price Content Rating               Genres  \
# 8513   5.000000e+06  Free   0.00       Everyone                Tools
# 3904   1.000000e+09  Free   0.00       Everyone        Communication
# 4542   5.000000e+04  Paid   1.99       Everyone               Arcade
# 7186   1.000000e+03  Free   0.00       Everyone            Lifestyle
# 8769   1.000000e+07  Free   0.00       Everyone  Casual;Pretend Play
# ...

# %% [markdown]
# ## saving the cleaned data

# %%
df.to_csv('Playstore_cleaned.csv', index=False)

# %% [markdown]
# ## Loading the cleaned dataset

# %%
df_new = pd.read_csv("Playstore_cleaned.csv")
df_new
# Out:
#                                              Application              section  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10341                                   Sya9a Maroc - FR               FAMILY
# 10342                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10343                             Parkinson Exercices FR              MEDICAL
# 10344                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10345      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## Summery Statistics

# %%
df.columns
# Out:
# Index(['Application', 'section', 'Rating', 'Reviews', 'Installs', 'item',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Size_MB'],
#       dtype='object')

# %% [markdown]
# ## Average(Mean)

# %%
print("Rating - ",df["Rating"].mean())
print("Reviews - ",df["Reviews"].mean())
print("Installs - ",df["Installs"].mean())
print("Price - ",df["Price"].mean())
print("Size_MB - ",df["Size_MB"].mean())
# Out:
# Rating -  4.203769572781751
# Reviews -  406333.77063599456
# Installs -  14172659.715542238
# Price -  1.0315609897544948
# Size_MB -  20.636903150976224

# %% [markdown]
# ## Median

# %%
print("Rating - ",df["Rating"].median())
print("Reviews - ",df["Reviews"].median())
print("Installs - ",df["Installs"].median())
print("Price - ",df["Price"].median())
print("Size_MB - ",df["Size_MB"].median())
# Out:
# Rating -  4.3
# Reviews -  1688.5
# Installs -  100000.0
# Price -  0.0
# Size_MB -  14.0

# %% [markdown]
# ## Mode

# %%
df['Rating'].mode()
# Out:
# 0    4.3
# Name: Rating, dtype: float64

# %%
df["Reviews"].mode()
# Out:
# 0    0.0
# Name: Reviews, dtype: float64

# %%
df["Installs"].mode()
# Out:
# 0    1000000.0
# Name: Installs, dtype: float64

# %%
df["Price"].mode()
# Out:
# 0    0.0
# Name: Price, dtype: float64

# %%
df["Size_MB"].mode()
# Out:
# 0    14.0
# Name: Size_MB, dtype: float64

# %%
df.select_dtypes(include='number').mean()
# Out:
# Rating      4.203770e+00
# Reviews     4.063338e+05
# Installs    1.417266e+07
# Price       1.031561e+00
# Size_MB     2.063690e+01
# dtype: float64

# %%
df.select_dtypes(include='number').median()
# Out:
# Rating           4.3
# Reviews       1688.5
# Installs    100000.0
# Price            0.0
# Size_MB         14.0
# dtype: float64

# %%
df.select_dtypes(include=object).mode()
# Out:
#   Application section  item Content Rating Genres         Current Ver  \
# 0      ROBLOX  FAMILY  Free       Everyone  Tools  Varies with device
#
#   Android Ver
# 0  4.1 and up

# %% [markdown]
# ## Standard Deviation

# %%
df.select_dtypes(include='number').std()
# Out:
# Rating      4.857300e-01
# Reviews     2.698179e+06
# Installs    8.028090e+07
# Price       1.628725e+01
# Size_MB     2.071994e+01
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10346 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Application     10346 non-null  object
#  1   section         10346 non-null  object
#  2   Rating          10346 non-null  float64
#  3   Reviews         10346 non-null  float64
#  4   Installs        10346 non-null  float64
#  5   item            10346 non-null  object
#  6   Price           10346 non-null  float64
#  7   Content Rating  10346 non-null  object
#  8   Genres          10346 non-null  object
#  9   Last Updated    10346 non-null  datetime64[ns]
#  10  Current Ver     10346 non-null  object
#  11  Android Ver     10346 non-null  object
#  12  Size_MB         10346 non-null  float64
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating       Reviews      Installs         Price  \
# count  10346.00000  1.034600e+04  1.034600e+04  10346.000000
# mean       4.20377  4.063338e+05  1.417266e+07      1.031561
# min        1.00000  0.000000e+00  0.000000e+00      0.000000
# 25%        4.10000  3.200000e+01  1.000000e+03      0.000000
# 50%        4.30000  1.688500e+03  1.000000e+05      0.000000
# 75%        4.50000  4.659825e+04  1.000000e+06      0.000000
# max        5.00000  7.815831e+07  1.000000e+09    400.000000
# std        0.48573  2.698179e+06  8.028090e+07     16.287252
#
#                         Last Updated       Size_MB
# count                          10346  10346.000000
# mean   2017-11-14 14:51:45.200077312     20.636903
# min              2010-05-21 00:00:00      1.000000
# 25%              2017-09-04 06:00:00      6.525000
# 50%              2018-05-20 00:00:00     14.000000
# 75%              2018-07-19 00:00:00     26.000000
# max              2018-08-08 00:00:00    100.000000
# ...

# %% [markdown]
# #### -There are around 10346 total data points
# - Average rating is 4.2,which means most of the apps are rated well
# - Ratings range from 1 to 5 and its SD is (~0.48)
#
# - There is a huge variation in reviews(0 to ~78M)
# - Mean is much higher than Median which indicates the outliers
#
# - Installs ranges from 0 to 1billion
# - Data is highly skewed in Reviews and Installs

# %%
df.describe(include=object)
# Out:
#        Application section   item Content Rating Genres         Current Ver  \
# count        10346   10346  10346          10346  10346               10346
# unique        9648      33      2              6    119                2783
# top         ROBLOX  FAMILY   Free       Everyone  Tools  Varies with device
# freq             9    1939   9584           8372    840                1301
#
#        Android Ver
# count        10346
# unique          33
# top     4.1 and up
# freq          2379

# %% [markdown]
# - There are 9648 unique apps which indicates that most of the apps are unique
# - ROBOX has the most repeats
# - Section Family is the most repeated
# - Most of the apps are suitable for everyone without any age restrictions
# - Most of the apps are free with 9584 out of 10346 are free apps
# - The top apps are used in Android Ver with 4.1 and up rating
# - There are 6 unique content ratings
# - The top genres is the tools

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Univariate analysis
# - Histogram,kde,box - numerical
# - Count, pie - categorical
#
# ### Bivariate analysis
# - Bar plot - Category vs Numerical
# - Line plot(Time series)and Scatter - Numerical vs Numerical
#
# ### Multivariate analysis
# - Heatmap - Correlation
# - Pair plot - proportion

# %% [markdown]
# ## Histogram
#
# - Distribution of numerical data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df,x="Rating") #To show the histogram plot of Rating
# Out:
# <Axes: xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(data=df,x="Reviews") #To show the histplot of Reviews
# Out:
# <Axes: xlabel='Reviews', ylabel='Count'>

# %%
sns.histplot(data=df,x="Price")
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df,x="Installs")
# Out:
# <Axes: xlabel='Installs', ylabel='Count'>

# %%
plt.figure(figsize=(7,5))  #Adjusting the figure size
sns.histplot(data=df,x="Size_MB",bins=40,color="purple")   #to show the plot of Size_MB, let the bars be in purple color and size of 40
plt.title("Sizes")     #To create a title
plt.xlabel("Size of Apps")    #To label the x-axes
plt.ylabel("No. of Apps")    #To label the Y-axes
plt.show()  #To show

# %%
plt.figure(figsize=(7,5))  #Adjusting the figure size
sns.histplot(data=df,x="Price",bins=40,color="Indigo", hue = "item")   #to show the plot of item, let the bars be in indigo color and size of 40
plt.title("items")     #To create a title
plt.xlabel("item of Apps")    #To label the x-axes
plt.ylabel("No. of Apps")    #To label the Y-axes
plt.show()  #To show

# %%
sns.kdeplot(data=df,x="Rating")
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %% [markdown]
# ## Box plot

# %%
sns.boxplot(data=df,x="Reviews")
# Out:
# <Axes: xlabel='Reviews'>

# %%
sns.boxplot(data=df,x="Rating")
# Out:
# <Axes: xlabel='Rating'>

# %% [markdown]
# ## Count plot

# %%
sns.countplot(data=df,x="Rating")
# Out:
# <Axes: xlabel='Rating', ylabel='count'>

# %%
sns.countplot(data=df,x="Size_MB")
# Out:
# <Axes: xlabel='Size_MB', ylabel='count'>

# %% [markdown]
# ## Pie plot

# %%
plt.pie(data=df,x="Installs")
# Out:
# ([<matplotlib.patches.Wedge at 0x23d464a6210>,
# ...
#   ...],
#  [Text(1.0999999999999748, 2.3567785376599026e-07, ''),
#   Text(1.0999999999317314, 1.2255248020411492e-05, ''),
#   Text(1.0999999908502798, 0.00014187806188372385, ''),
#   Text(1.0999990599321288, 0.001438105849193456, ''),
#   Text(1.099996882552658, 0.002618849830314191, ''),
#   Text(1.0999968741306192, 0.002622384957793719, ''),
#   Text(1.0999968685096149, 0.0026247417094316925, ''),
#   Text(1.0999968091842143, 0.002649487600900923, ''),
#   Text(1.0999966946421416, 0.0026966231407768906, ''),
#   Text(1.0999966360309834, 0.0027204265327543443, ''),
#   Text(1.0999965769047317, 0.0027442299234579086, ''),
#   Text(1.0999964583035422, 0.002791365197180691, ''),
#   Text(1.0999957698912286, 0.0030506100051137922, ''),
#   Text(1.0999950839994204, 0.003288643657826079, ''),
#   Text(1.099995069897434, 0.0032933571534131223, ''),
#   Text(1.0999950274695194, 0.003307497895923632, ''),
# ...

# %%
plt.pie(data=df,x="Price")
# Out:
# ([<matplotlib.patches.Wedge at 0x23d531f4410>,
# ...
#   ...],
#  [Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
#   Text(1.1, 0.0, ''),
# ...

# %% [markdown]
# ## Bar plot

# %%
sns.barplot(data=df,x="Reviews",y="item")
# Out:
# <Axes: xlabel='Reviews', ylabel='item'>

# %% [markdown]
# ## Line plot

# %%
sns.lineplot(data=df,x="Rating",y="Size_MB",color="violet")
# Out:
# <Axes: xlabel='Rating', ylabel='Size_MB'>

# %%
sns.lineplot(data=df,x="Installs",y="Reviews")
# Out:
# <Axes: xlabel='Installs', ylabel='Reviews'>

# %% [markdown]
# ## Scatter plot

# %%
sns.scatterplot(data=df,x="Rating",y="Reviews")
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>

# %%
sns.scatterplot(data=df,x="Reviews",y="Installs")
# Out:
# <Axes: xlabel='Reviews', ylabel='Installs'>

# %% [markdown]
# ## Heat map
